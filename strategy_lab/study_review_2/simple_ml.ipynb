# %%
import os
import pandas as pd
import numpy as np

# Change the working directory to strategy_lab
os.chdir("/Users/sugang/Desktop/projects/2024coin/strategy_lab")

# Now, you can read the CSV file without specifying the full path
df = pd.read_csv("1/full_data_with_predictions.csv", index_col=0)
df
# Out:
#                    open         high          low        close    volume_krw  \
# time_utc
# 2017-10-01    4889000.0    4978000.0    4682000.0    4962000.0  1.331325e+08
# 2017-10-02    4962000.0    5095000.0    4956000.0    5025000.0  1.599315e+08
# 2017-10-03    5021000.0    5079000.0    4811000.0    4964000.0  5.890130e+07
# 2017-10-04    4987000.0    5002000.0    4837000.0    4895000.0  3.458813e+07
# 2017-10-05    4894000.0    4993000.0    4811000.0    4926000.0  2.637132e+07
# ...                 ...          ...          ...          ...           ...
# 2024-11-09  106845000.0  106990000.0  105873000.0  106294000.0  2.876788e+11
# 2024-11-10  106294000.0  112470000.0  106050000.0  111440000.0  8.895481e+11
# 2024-11-11  111440000.0  125073000.0  111273000.0  124503000.0  1.413171e+12
# 2024-11-12  124476000.0  128010000.0  118864000.0  124967000.0  2.115376e+12
# 2024-11-13  124951000.0  126725000.0  122771000.0  125314000.0  4.659916e+11
#
#             volume_market  Daily Return  predict_close
# time_utc
# 2017-10-01      27.323332      0.013687      4303650.5
# 2017-10-02      31.728004      0.012696      4412025.5
# 2017-10-03      11.899307     -0.012139      4474568.0
# 2017-10-04       7.038744     -0.013900      4504902.5
# 2017-10-05       5.363652      0.006333      4504320.0
# ...                   ...           ...            ...
# 2024-11-09    2702.452888     -0.005138     98971560.0
# 2024-11-10    8111.036561      0.048413    101134830.0
# 2024-11-11   12056.831324      0.117220    103599640.0
# 2024-11-12   17037.759563      0.003727    107227736.0
# 2024-11-13    3738.454304      0.002777    109781450.0
#
# [2601 rows x 8 columns]

# %%
df["signal"] = 0
df["signal"] = np.where(df["predict_close"] > df["close"].shift(1), 1, 0)
df["strategy_returns2"] = df["signal"] * ((df["close"] * 0.998 - df["open"] * 1.002) / df["open"] * 1.002)
df["cumulative_returns2"] = (1 + df["strategy_returns2"]).cumprod()
df.to_csv("2/temp2.csv")
