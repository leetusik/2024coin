# %%
import pandas as pd
import numpy as np

df = pd.read_excel("data/btc_search_data.xlsx")
df
# Out:
#             Date     score     price2
# 0     2021-03-31  18.81801  70.211702
# 1     2021-04-01  18.64159  70.975406
# 2     2021-04-02  23.80083  71.960334
# 3     2021-04-03  18.43446  70.301153
# 4     2021-04-04  18.03496  74.325507
# ...          ...       ...        ...
# 1231  2024-08-13   8.53058  79.575250
# 1232  2024-08-14   8.50020  78.329662
# 1233  2024-08-15   7.02056  79.748382
# 1234  2024-08-16   9.99033  79.607953
# 1235  2024-08-17   6.18067  79.766657
#
# [1236 rows x 3 columns]

# %%
df["ma10"] = df["score"].rolling(window=10).mean()

# %%
import matplotlib.pyplot as plt

# Assuming 'df' is your DataFrame containing the columns 'Date', 'score', and 'price2'

# Plotting the data
plt.figure(figsize=(14, 7))

# Plot 'score' over time
plt.plot(df['Date'], df['score'], label='Score', color='blue', linewidth=2)

# Plot 'price2' over time
plt.plot(df['Date'], df['price2'], label='Price2', color='green', linewidth=2)

plt.plot(df['Date'], df['ma10'], label='ma10', color='red', linewidth=2)

# Adding titles and labels
plt.title('Score and Price2 Over Time', fontsize=16)
plt.xlabel('Date', fontsize=14)
plt.ylabel('Values', fontsize=14)

# Adding a legend
plt.legend()

# Adding gridlines for better readability
plt.grid(True)

# Rotating the x-axis labels for better readability
plt.xticks(rotation=45)

# Displaying the plot
plt.tight_layout()
plt.show()
