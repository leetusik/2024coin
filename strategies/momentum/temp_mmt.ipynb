# %%
import pandas as pd
import numpy as np
import sys
import os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '../../')))



df = pd.read_csv(os.path.join(os.getcwd(), "../../data/total_4am.csv"), index_col=0)

# %%
import pandas as pd
from performance import get_performance, draw_graph

def various_momentum(momentum_list, ma_list, df):

    original_df = df.copy()  # Make a copy of the original DataFrame
    
    for momentum in momentum_list:
        for ma in ma_list:    
            df = original_df.copy()  # Create a fresh copy for each momentum
            df[f"ma_{ma}"] = df["close"].rolling(window=ma).mean()
            df[f"{momentum}_momentum"] = 0

            # Implement RSI strategy for long positions only
            df['signal'] = 0  # Default to no position
            max_range = max(ma, momentum)
            for i in range(max_range, len(df)):
                df.loc[i, f"{momentum}_momentum"] = df.loc[i, "close"] - df.loc[i-momentum, "close"]
                # Buy condition
                if df[f'{momentum}_momentum'].iloc[i] >= 0 and df.loc[i, "close"] > df.loc[i, f"ma_{ma}"] and df[f'{momentum}_momentum'].iloc[i-1] < 0:
                    df.loc[i, 'signal'] = 1
                # Sell condition
                elif df[f'{momentum}_momentum'].iloc[i] < 0 and df[f'{momentum}_momentum'].iloc[i-1] >= 0:
                    df.loc[i, 'signal'] = -1
            # # Manage positions with stop loss, take profit, and sell signal
            # df['position'] = 0
            # df['entry_price'] = np.nan
            # df['exit_price'] = np.nan
            # holding_position = False

            # for i in range(1, len(df)):
            #     if df['signal'].iloc[i] == 1 and not holding_position:
            #         # Enter position
            #         df.loc[i, 'position'] = 1
            #         df.loc[i, 'entry_price'] = df.loc[i, 'close']
            #         holding_position = True
            #     elif holding_position:
            #         # Calculate percentage change since entry
            #         entry_price = df['entry_price'].iloc[i-1]
            #         current_price = df['close'].iloc[i]
            #         percent_change = (current_price - entry_price) / entry_price * 100

            #         if df['signal'].iloc[i] == -1:  # Sell signal condition
            #             # print(f"cond1 on{i}")
            #             df.loc[i, 'position'] = 0
            #             df.loc[i, 'exit_price'] = current_price
            #             holding_position = False
            #         elif percent_change <= -5:  # Stop loss condition
            #             # print(f"cond2 on{i}")
            #             df.loc[i, 'position'] = 0
            #             df.loc[i, 'exit_price'] = current_price
            #             holding_position = False
            #         # elif percent_change >= 30:  # Take profit condition
            #         #     print(f"cond3 on{i}")
            #         #     df['position'].iloc[i] = 0
            #         #     df['exit_price'].iloc[i] = current_price
            #         #     holding_position = False
            #         else:
            #             # Continue holding the position if no sell conditions are met
            #             # df['position'].iloc[i] = df['position'].iloc[i-1]
            #             df.loc[i, 'position'] = df.loc[i-1, 'position']
            #             # df['entry_price'].iloc[i] = df['entry_price'].iloc[i-1]
            #             df.loc[i, 'entry_price'] = df.loc[i-1, 'entry_price']
            #     else:
            #         # No signal and no position
            #         # df['position'].iloc[i] = df['position'].iloc[i-1]
            #         df.loc[i, 'position'] = df.loc[i-1, 'position']

            # Manage positions with stop loss, take profit, and sell signal
            df['position'] = 0
            df['highest_price'] = np.nan
            df['exit_price'] = np.nan
            holding_position = False

            for i in range(1, len(df)):
                if df['signal'].iloc[i] == 1 and not holding_position:
                    # Enter position
                    df.loc[i, 'position'] = 1
                    df.loc[i, 'highest_price'] = df.loc[i, 'close']
                    holding_position = True
                elif holding_position:
                    # Calculate percentage change since entry
                    # df['highest_price'].iloc[i] = max(df['highest_price'].iloc[i-1], df['close'].iloc[i])
                    df.loc[i, 'highest_price'] = max(df.loc[i-1, 'highest_price'], df.loc[i-1, 'close'])
                    highest_price = df['highest_price'].iloc[i]
                    current_price = df['close'].iloc[i]
                    percent_change = (current_price - highest_price) / highest_price * 100

                    if df['signal'].iloc[i] == -1:  # Sell signal condition
                        # print(f"cond1 on{i}")
                        df.loc[i, 'position'] = 0
                        df.loc[i, 'exit_price'] = current_price
                        holding_position = False
                    elif percent_change <= -5:  # Stop loss condition
                        # print(f"cond2 on{i}")
                        df.loc[i, 'position'] = 0
                        df.loc[i, 'exit_price'] = current_price
                        holding_position = False
                    else:
                        # Continue holding the position if no sell conditions are met
                        df.loc[i, 'position'] = df.loc[i-1, 'position']

                else:
                    # No signal and no position
                    # df['position'].iloc[i] = df['position'].iloc[i-1]
                    df.loc[i, 'position'] = df.loc[i-1, 'position']
                    
            # Calculate the strategy returns (only when in a long position)
            df['strategy_returns'] = df['position'].shift(1) * df['close'].pct_change()

            df['strategy_returns2'] = df['strategy_returns']
            
            for i in range(1, len(df)):
                buy_price = df.loc[i-1, "close"]
                buy_price_copy = buy_price
                sell_price = df.loc[i, "close"]
                sell_price_copy = sell_price
                if df.loc[i-1, 'position'] == 1 and df.loc[i-1, 'signal'] == 1:
                    # df.loc[i, 'strategy_returns2'] = (df.loc[i,'position'])/(df.loc[i-1, 'position'] * 1.002) -1
                    buy_price = df.loc[i-1, "close"] * 1.002
                if df.loc[i, 'position'] == 0 and df.loc[i-1, 'position'] != 0:
                    # df.loc[i, 'strategy_returns2'] = (df.loc[i,'position'] * 0.998)/(df.loc[i-1, 'position']) -1
                    sell_price = df.loc[i, "close"] * 0.998
                
                if buy_price == buy_price_copy and sell_price == sell_price_copy:
                    continue


                df.loc[i, "strategy_returns2"] = sell_price/buy_price - 1

            df['cumulative_returns'] = (1 + df['strategy_returns']).cumprod()

            df["cumulative_returns2"] = (1 + df['strategy_returns2']).cumprod()

            # Calculate the benchmark cumulative returns (buy and hold strategy)
            df['benchmark_returns'] = (1 + df['close'].pct_change()).cumprod()

            # Save the results to a CSV file
            # df.to_csv(f"../../results/momentum/simple_mmt_{(momentum)}_cut_highest.csv")

            # Get performance metrics and plot the results
            excel_path = "../../results/results.xlsx"
            # get_performance(df=df, title=f"simple_mmt_{momentum}_cut_highest5%", add_to_excel=True, file_path=excel_path)
            get_performance(df=df, title=f"simple_mmt_{momentum}_{ma}_cut_highest5%")
            # draw_graph(df=df)

            
        df = original_df.copy()  # Create a fresh copy for each momentum
    
    # print(cagr_mean, mdd_mean)

# %%
# momentum_list = [30, 60, 90, 120, 150, 180, 360]
momentum_list = [30, 60, 90, 120, 150, 180]
ma_list = [5, 10, 20, 50, 90, 120, 200]
various_momentum(momentum_list=momentum_list, ma_list=ma_list, df=df,)
# Out:
# ======Investment Summary======
# Strategy        : simple_mmt_30_5_cut_highest5%
# total_return    : 278.55
# cagr            : 54.25
# mdd             : 21.28
# total_return_w_fee : 230.41
# cagr_w_fee      : 47.57
# mdd_w_fee       : 22.99
# investing_days  : 1121
# ==============================
# ======Investment Summary======
# Strategy        : simple_mmt_30_10_cut_highest5%
# total_return    : 190.26
# cagr            : 41.48
# mdd             : 19.71
# total_return_w_fee : 158.47
# cagr_w_fee      : 36.23
# mdd_w_fee       : 23.32
# investing_days  : 1121
# ==============================
# ======Investment Summary======
# Strategy        : simple_mmt_30_20_cut_highest5%
# total_return    : 201.84
# cagr            : 43.29
# mdd             : 18.64
# total_return_w_fee : 173.11
# cagr_w_fee      : 38.7
# mdd_w_fee       : 21.36
# investing_days  : 1121
# ==============================
# ======Investment Summary======
# Strategy        : simple_mmt_30_50_cut_highest5%
# total_return    : 173.76
# cagr            : 38.81
# mdd             : 18.45
# total_return_w_fee : 150.7
# cagr_w_fee      : 34.89
# mdd_w_fee       : 20.23
# investing_days  : 1121
# ==============================
# ======Investment Summary======
# Strategy        : simple_mmt_30_90_cut_highest5%
# total_return    : 71.49
# cagr            : 20.2
# mdd             : 21.07
# total_return_w_fee : 57.67
# cagr_w_fee      : 16.8
# mdd_w_fee       : 22.48
# investing_days  : 1070
# ==============================
# ======Investment Summary======
# Strategy        : simple_mmt_30_120_cut_highest5%
# total_return    : 81.19
# cagr            : 22.48
# mdd             : 21.4
# total_return_w_fee : 66.59
# cagr_w_fee      : 19.02
# mdd_w_fee       : 22.49
# investing_days  : 1070
# ==============================
# ======Investment Summary======
# Strategy        : simple_mmt_30_200_cut_highest5%
# total_return    : 58.16
# cagr            : 18.35
# mdd             : 14.72
# total_return_w_fee : 47.17
# cagr_w_fee      : 15.26
# mdd_w_fee       : 17.41
# investing_days  : 993
# ==============================
# ======Investment Summary======
# Strategy        : simple_mmt_60_5_cut_highest5%
# total_return    : 75.3
# cagr            : 20.11
# mdd             : 30.72
# total_return_w_fee : 63.78
# cagr_w_fee      : 17.48
# mdd_w_fee       : 33.04
# investing_days  : 1118
# ==============================
# ======Investment Summary======
# Strategy        : simple_mmt_60_10_cut_highest5%
# total_return    : 84.48
# cagr            : 22.13
# mdd             : 28.09
# total_return_w_fee : 73.74
# cagr_w_fee      : 19.76
# mdd_w_fee       : 30.21
# investing_days  : 1118
# ==============================
# ======Investment Summary======
# Strategy        : simple_mmt_60_20_cut_highest5%
# total_return    : 82.29
# cagr            : 21.66
# mdd             : 28.94
# total_return_w_fee : 70.99
# cagr_w_fee      : 19.14
# mdd_w_fee       : 31.32
# investing_days  : 1118
# ==============================
# ======Investment Summary======
# Strategy        : simple_mmt_60_50_cut_highest5%
# total_return    : 87.61
# cagr            : 22.8
# mdd             : 24.51
# total_return_w_fee : 76.68
# cagr_w_fee      : 20.42
# mdd_w_fee       : 26.45
# investing_days  : 1118
# ==============================
# ======Investment Summary======
# Strategy        : simple_mmt_60_90_cut_highest5%
# total_return    : 75.29
# cagr            : 20.11
# mdd             : 22.38
# total_return_w_fee : 67.08
# cagr_w_fee      : 18.24
# mdd_w_fee       : 24.22
# investing_days  : 1118
# ==============================
# ======Investment Summary======
# Strategy        : simple_mmt_60_120_cut_highest5%
# total_return    : 70.92
# cagr            : 25.45
# mdd             : 17.61
# total_return_w_fee : 64.22
# cagr_w_fee      : 23.34
# mdd_w_fee       : 18.92
# investing_days  : 863
# ==============================
# ======Investment Summary======
# Strategy        : simple_mmt_60_200_cut_highest5%
# total_return    : 99.77
# cagr            : 81.17
# mdd             : 17.62
# total_return_w_fee : 93.47
# cagr_w_fee      : 76.26
# mdd_w_fee       : 19.41
# investing_days  : 425
# ==============================
# ======Investment Summary======
# Strategy        : simple_mmt_90_5_cut_highest5%
# total_return    : 4.59
# cagr            : 1.5
# mdd             : 34.22
# total_return_w_fee : -1.11
# cagr_w_fee      : -0.37
# mdd_w_fee       : 37.05
# investing_days  : 1100
# ==============================
# ======Investment Summary======
# Strategy        : simple_mmt_90_10_cut_highest5%
# total_return    : 1.79
# cagr            : 0.59
# mdd             : 33.25
# total_return_w_fee : -2.98
# cagr_w_fee      : -1.0
# mdd_w_fee       : 35.87
# investing_days  : 1100
# ==============================
# ======Investment Summary======
# Strategy        : simple_mmt_90_20_cut_highest5%
# total_return    : 8.64
# cagr            : 2.79
# mdd             : 28.76
# total_return_w_fee : 3.14
# cagr_w_fee      : 1.03
# mdd_w_fee       : 31.82
# investing_days  : 1100
# ==============================
# ======Investment Summary======
# Strategy        : simple_mmt_90_50_cut_highest5%
# total_return    : 20.37
# cagr            : 6.34
# mdd             : 22.68
# total_return_w_fee : 14.27
# cagr_w_fee      : 4.52
# mdd_w_fee       : 24.51
# investing_days  : 1100
# ==============================
# ======Investment Summary======
# Strategy        : simple_mmt_90_90_cut_highest5%
# total_return    : 6.52
# cagr            : 2.12
# mdd             : 30.15
# total_return_w_fee : -0.08
# cagr_w_fee      : -0.03
# mdd_w_fee       : 33.95
# investing_days  : 1100
# ==============================
# ======Investment Summary======
# Strategy        : simple_mmt_90_120_cut_highest5%
# total_return    : 6.38
# cagr            : 2.07
# mdd             : 30.24
# total_return_w_fee : 0.18
# cagr_w_fee      : 0.06
# mdd_w_fee       : 33.77
# investing_days  : 1100
# ==============================
# ======Investment Summary======
# Strategy        : simple_mmt_90_200_cut_highest5%
# total_return    : 17.45
# cagr            : 10.73
# mdd             : 22.56
# total_return_w_fee : 12.39
# cagr_w_fee      : 7.68
# mdd_w_fee       : 24.7
# investing_days  : 576
# ==============================
# ======Investment Summary======
# Strategy        : simple_mmt_120_5_cut_highest5%
# total_return    : 21.21
# cagr            : 6.78
# mdd             : 18.47
# total_return_w_fee : 16.46
# cagr_w_fee      : 5.33
# mdd_w_fee       : 20.09
# investing_days  : 1070
# ==============================
# ======Investment Summary======
# Strategy        : simple_mmt_120_10_cut_highest5%
# total_return    : 29.29
# cagr            : 17.68
# mdd             : 12.57
# total_return_w_fee : 25.21
# cagr_w_fee      : 15.31
# mdd_w_fee       : 13.62
# investing_days  : 576
# ==============================
# ======Investment Summary======
# Strategy        : simple_mmt_120_20_cut_highest5%
# total_return    : 31.88
# cagr            : 19.17
# mdd             : 12.57
# total_return_w_fee : 28.24
# cagr_w_fee      : 17.07
# mdd_w_fee       : 13.62
# investing_days  : 576
# ==============================
# ======Investment Summary======
# Strategy        : simple_mmt_120_50_cut_highest5%
# total_return    : 30.68
# cagr            : 9.56
# mdd             : 13.83
# total_return_w_fee : 27.07
# cagr_w_fee      : 8.52
# mdd_w_fee       : 14.86
# investing_days  : 1070
# ==============================
# ======Investment Summary======
# Strategy        : simple_mmt_120_90_cut_highest5%
# total_return    : 22.7
# cagr            : 7.23
# mdd             : 13.52
# total_return_w_fee : 19.79
# cagr_w_fee      : 6.35
# mdd_w_fee       : 14.38
# investing_days  : 1070
# ==============================
# ======Investment Summary======
# Strategy        : simple_mmt_120_120_cut_highest5%
# total_return    : 22.7
# cagr            : 7.23
# mdd             : 13.52
# total_return_w_fee : 19.79
# cagr_w_fee      : 6.35
# mdd_w_fee       : 14.38
# investing_days  : 1070
# ==============================
# ======Investment Summary======
# Strategy        : simple_mmt_120_200_cut_highest5%
# total_return    : 24.29
# cagr            : 14.77
# mdd             : 10.17
# total_return_w_fee : 21.34
# cagr_w_fee      : 13.04
# mdd_w_fee       : 10.7
# investing_days  : 576
# ==============================
# ======Investment Summary======
# Strategy        : simple_mmt_150_5_cut_highest5%
# total_return    : 2.5
# cagr            : 0.87
# mdd             : 13.92
# total_return_w_fee : 0.47
# cagr_w_fee      : 0.16
# mdd_w_fee       : 15.46
# investing_days  : 1044
# ==============================
# ======Investment Summary======
# Strategy        : simple_mmt_150_10_cut_highest5%
# total_return    : 2.5
# cagr            : 0.87
# mdd             : 13.92
# total_return_w_fee : 0.47
# cagr_w_fee      : 0.16
# mdd_w_fee       : 15.46
# investing_days  : 1044
# ==============================
# ======Investment Summary======
# Strategy        : simple_mmt_150_20_cut_highest5%
# total_return    : 2.5
# cagr            : 0.87
# mdd             : 13.92
# total_return_w_fee : 0.47
# cagr_w_fee      : 0.16
# mdd_w_fee       : 15.46
# investing_days  : 1044
# ==============================
# ======Investment Summary======
# Strategy        : simple_mmt_150_50_cut_highest5%
# total_return    : 67.97
# cagr            : 19.88
# mdd             : 13.04
# total_return_w_fee : 63.98
# cagr_w_fee      : 18.88
# mdd_w_fee       : 13.74
# investing_days  : 1044
# ==============================
# ======Investment Summary======
# Strategy        : simple_mmt_150_90_cut_highest5%
# total_return    : 57.77
# cagr            : 17.28
# mdd             : 8.7
# total_return_w_fee : 54.65
# cagr_w_fee      : 16.47
# mdd_w_fee       : 9.07
# investing_days  : 1044
# ==============================
# ======Investment Summary======
# Strategy        : simple_mmt_150_120_cut_highest5%
# total_return    : 59.23
# cagr            : 17.66
# mdd             : 8.7
# total_return_w_fee : 56.08
# cagr_w_fee      : 16.84
# mdd_w_fee       : 9.07
# investing_days  : 1044
# ==============================
# ======Investment Summary======
# Strategy        : simple_mmt_150_200_cut_highest5%
# total_return    : 41.83
# cagr            : 24.89
# mdd             : 9.26
# total_return_w_fee : 39.03
# cagr_w_fee      : 23.31
# mdd_w_fee       : 10.16
# investing_days  : 574
# ==============================
# ======Investment Summary======
# Strategy        : simple_mmt_180_5_cut_highest5%
# total_return    : 65.51
# cagr            : 19.36
# mdd             : 16.93
# total_return_w_fee : 58.38
# cagr_w_fee      : 17.53
# mdd_w_fee       : 18.41
# investing_days  : 1039
# ==============================
# ======Investment Summary======
# Strategy        : simple_mmt_180_10_cut_highest5%
# total_return    : 72.38
# cagr            : 21.08
# mdd             : 13.48
# total_return_w_fee : 65.62
# cagr_w_fee      : 19.39
# mdd_w_fee       : 14.69
# investing_days  : 1039
# ==============================
# ======Investment Summary======
# Strategy        : simple_mmt_180_20_cut_highest5%
# total_return    : 73.36
# cagr            : 21.32
# mdd             : 12.99
# total_return_w_fee : 67.23
# cagr_w_fee      : 19.8
# mdd_w_fee       : 13.85
# investing_days  : 1039
# ==============================
# ======Investment Summary======
# Strategy        : simple_mmt_180_50_cut_highest5%
# total_return    : 73.36
# cagr            : 21.32
# mdd             : 12.99
# total_return_w_fee : 67.23
# cagr_w_fee      : 19.8
# mdd_w_fee       : 13.85
# investing_days  : 1039
# ==============================
# ======Investment Summary======
# Strategy        : simple_mmt_180_90_cut_highest5%
# total_return    : 83.52
# cagr            : 23.77
# mdd             : 7.89
# total_return_w_fee : 78.45
# cagr_w_fee      : 22.56
# mdd_w_fee       : 8.08
# investing_days  : 1039
# ==============================
# ======Investment Summary======
# Strategy        : simple_mmt_180_120_cut_highest5%
# total_return    : 71.9
# cagr            : 20.96
# mdd             : 7.89
# total_return_w_fee : 67.82
# cagr_w_fee      : 19.95
# mdd_w_fee       : 8.09
# investing_days  : 1039
# ==============================
# ======Investment Summary======
# Strategy        : simple_mmt_180_200_cut_highest5%
# total_return    : 74.02
# cagr            : 42.14
# mdd             : 7.53
# total_return_w_fee : 70.57
# cagr_w_fee      : 40.35
# mdd_w_fee       : 7.9
# investing_days  : 575
# ==============================
