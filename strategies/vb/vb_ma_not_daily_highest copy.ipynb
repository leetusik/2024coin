# %%
import pandas as pd
import numpy as np
import sys
import os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '../../')))



df = pd.read_csv(os.path.join(os.getcwd(), "../../data/total_4am.csv"), index_col=0)

# %%
from performance import get_performance

def get_results(k, df, ma):

    original_df = df.copy()  # Make a copy of the original DataFrame
    df["range"] = df["high"] - df["low"]
    df["target_price"] = 0
    for i in range(1, len(df)):
        df.loc[i, "target_price"] = df.loc[i-1, "range"] * k + df.loc[i, "open"]

    df[f"ma_{ma}"] = df["open"].rolling(window=ma).mean()

    
    # for i in range(1, len(df)):
    #     # Buy condition
    #     if df.loc[i, "high"] >= df.loc[i, "target_price"] and signal_before == False:
    #         df.loc[i, 'signal'] = 1
    #         signal_before = True
        

    # # Manage positions with stop loss, take profit, and sell signal
    df['signal'] = 0  # Default to no position
    df['position'] = 0
    df['entry_price'] = np.nan
    df['exit_price'] = np.nan
    holding_position = False
    signal_before = False

    for i in range(1, len(df)):
        if df.loc[i, "high"] >= df.loc[i, "target_price"] and signal_before == False and df.loc[i, "open"] >= df.loc[i, f"ma_{ma}"]:
            df.loc[i, 'signal'] = 1
            signal_before = True

        if df['signal'].iloc[i] == 1 and not holding_position:
            # Enter position
            df.loc[i, 'position'] = 1
            df.loc[i, 'entry_price'] = df.loc[i, 'target_price']
            holding_position = True

        elif holding_position:
            # Calculate percentage change since entry
            entry_price = df['entry_price'].iloc[i-1]
            current_price = df['close'].iloc[i]
            percent_change = (current_price - entry_price) / entry_price * 100

            if percent_change <= -5:  # Stop loss condition
                # print(f"cond2 on{i}")
                df.loc[i, 'position'] = 0
                df.loc[i, 'exit_price'] = current_price
                holding_position = False
                signal_before = False

            # elif percent_change >= 30:  # Take profit condition
            #     print(f"cond3 on{i}")
            #     df['position'].iloc[i] = 0
            #     df['exit_price'].iloc[i] = current_price
            #     holding_position = False
            else:
                df.loc[i, 'position'] = df.loc[i-1, 'position']
                df.loc[i, 'entry_price'] = df.loc[i-1, 'entry_price']
        else:
            df.loc[i, 'position'] = df.loc[i-1, 'position']

    # Calculate the strategy returns (only when in a long position)
    df['strategy_returns'] = df['position'].shift(1) * df['close'].pct_change()
    df['strategy_returns2'] = df["strategy_returns"]

    for i in range(1, len(df)):
        buy_price = df.loc[i-1, "target_price"]
        buy_price_copy = buy_price
        sell_price = df.loc[i, "close"]
        sell_price_copy = sell_price

        if df.loc[i-1, 'position'] == 1 and df.loc[i-1, 'signal'] == 1:
            # df.loc[i, 'strategy_returns2'] = (df.loc[i,'position'])/(df.loc[i-1, 'position'] * 1.002) -1
            buy_price = df.loc[i-1, "target_price"] * 1.002
        if df.loc[i, 'position'] == 0 and df.loc[i-1, 'position'] != 0:
            # df.loc[i, 'strategy_returns2'] = (df.loc[i,'position'] * 0.998)/(df.loc[i-1, 'position']) -1
            buy_price = df.loc[i-1, "close"]
            sell_price = df.loc[i, "close"] * 0.998
        
        if buy_price == buy_price_copy and sell_price == sell_price_copy:            
            continue
        
        # df.loc[i, "strategy_returns"] = sell_price_copy/buy_price_copy -1
        df.loc[i, "strategy_returns2"] = sell_price/buy_price - 1


    df['cumulative_returns'] = (1 + df['strategy_returns']).cumprod()

    df["cumulative_returns2"] = (1 + df['strategy_returns2']).cumprod()


    # Calculate the benchmark cumulative returns (buy and hold strategy)
    df['benchmark_returns'] = (1 + df['close'].pct_change()).cumprod()

    # Save the results to a CSV file
    df.to_csv(f"../../results/volatilitybreakout/volatility_breakout_cut_highest_{k}_{ma}.csv")

    # Get performance metrics and plot the results
    excel_path = "../../results/results.xlsx"
    get_performance(df=df, title=f"Volatility Breakout_{k}_{ma}cut_highest5%", add_to_excel=True, file_path=excel_path)

    df = original_df.copy()  # Create a fresh copy for each interval

# %%
ks = [0.3, 0.5, 0.7, 0.9]
mas = [5, 10, 20, 50, 120, 200]
for k in ks:
    for ma in mas:
        get_results(k=k, df=df, ma=ma)
# Out:
# ======Investment Summary======
# Strategy        : Volatility Breakout_0.3_5cut_highest5%
# total_return    : 81.62
# cagr            : 19.36
# mdd             : 63.9
# total_return_w_fee : 75.6
# cagr_w_fee      : 18.17
# mdd_w_fee       : 64.72
# investing_days  : 1231
# ==============================
# ======Investment Summary======
# Strategy        : Volatility Breakout_0.3_10cut_highest5%
# total_return    : 122.63
# cagr            : 26.86
# mdd             : 63.53
# total_return_w_fee : 105.84
# cagr_w_fee      : 23.93
# mdd_w_fee       : 64.91
# investing_days  : 1228
# ==============================
# ======Investment Summary======
# Strategy        : Volatility Breakout_0.3_20cut_highest5%
# total_return    : 89.24
# cagr            : 21.37
# mdd             : 63.31
# total_return_w_fee : 104.71
# cagr_w_fee      : 24.3
# mdd_w_fee       : 63.58
# investing_days  : 1202
# ==============================
# ======Investment Summary======
# Strategy        : Volatility Breakout_0.3_50cut_highest5%
# total_return    : 107.85
# cagr            : 26.93
# mdd             : 65.66
# total_return_w_fee : 130.5
# cagr_w_fee      : 31.28
# mdd_w_fee       : 66.74
# investing_days  : 1120
# ==============================
# ======Investment Summary======
# Strategy        : Volatility Breakout_0.3_120cut_highest5%
# total_return    : 143.02
# cagr            : 34.05
# mdd             : 50.42
# total_return_w_fee : 151.87
# cagr_w_fee      : 35.64
# mdd_w_fee       : 50.25
# investing_days  : 1106
# ==============================
# ======Investment Summary======
# Strategy        : Volatility Breakout_0.3_200cut_highest5%
# total_return    : 86.19
# cagr            : 24.48
# mdd             : 43.13
# total_return_w_fee : 108.01
# cagr_w_fee      : 29.44
# mdd_w_fee       : 37.29
# investing_days  : 1036
# ==============================
# ======Investment Summary======
# Strategy        : Volatility Breakout_0.5_5cut_highest5%
# total_return    : 113.05
# cagr            : 25.16
# mdd             : 64.67
# total_return_w_fee : 86.19
# cagr_w_fee      : 20.26
# mdd_w_fee       : 65.21
# investing_days  : 1230
# ==============================
# ======Investment Summary======
# Strategy        : Volatility Breakout_0.5_10cut_highest5%
# total_return    : 114.4
# cagr            : 25.47
# mdd             : 63.69
# total_return_w_fee : 107.86
# cagr_w_fee      : 24.32
# mdd_w_fee       : 65.32
# investing_days  : 1227
# ==============================
# ======Investment Summary======
# Strategy        : Volatility Breakout_0.5_20cut_highest5%
# total_return    : 103.83
# cagr            : 24.14
# mdd             : 61.85
# total_return_w_fee : 115.48
# cagr_w_fee      : 26.25
# mdd_w_fee       : 63.03
# investing_days  : 1202
# ==============================
# ======Investment Summary======
# Strategy        : Volatility Breakout_0.5_50cut_highest5%
# total_return    : 96.4
# cagr            : 24.6
# mdd             : 65.61
# total_return_w_fee : 125.72
# cagr_w_fee      : 30.38
# mdd_w_fee       : 66.38
# investing_days  : 1120
# ==============================
# ======Investment Summary======
# Strategy        : Volatility Breakout_0.5_120cut_highest5%
# total_return    : 128.65
# cagr            : 31.38
# mdd             : 53.35
# total_return_w_fee : 146.49
# cagr_w_fee      : 34.68
# mdd_w_fee       : 50.79
# investing_days  : 1106
# ==============================
# ======Investment Summary======
# Strategy        : Volatility Breakout_0.5_200cut_highest5%
# total_return    : 87.38
# cagr            : 24.76
# mdd             : 42.58
# total_return_w_fee : 106.75
# cagr_w_fee      : 29.16
# mdd_w_fee       : 37.09
# investing_days  : 1036
# ==============================
# ======Investment Summary======
# Strategy        : Volatility Breakout_0.7_5cut_highest5%
# total_return    : 64.36
# cagr            : 15.89
# mdd             : 72.61
# total_return_w_fee : 58.76
# cagr_w_fee      : 14.7
# mdd_w_fee       : 73.49
# investing_days  : 1230
# ==============================
# ======Investment Summary======
# Strategy        : Volatility Breakout_0.7_10cut_highest5%
# total_return    : 60.22
# cagr            : 15.05
# mdd             : 71.5
# total_return_w_fee : 60.67
# cagr_w_fee      : 15.15
# mdd_w_fee       : 72.67
# investing_days  : 1227
# ==============================
# ======Investment Summary======
# Strategy        : Volatility Breakout_0.7_20cut_highest5%
# total_return    : 57.11
# cagr            : 14.72
# mdd             : 71.93
# total_return_w_fee : 66.4
# cagr_w_fee      : 16.74
# mdd_w_fee       : 72.85
# investing_days  : 1201
# ==============================
# ======Investment Summary======
# Strategy        : Volatility Breakout_0.7_50cut_highest5%
# total_return    : 136.12
# cagr            : 32.31
# mdd             : 58.66
# total_return_w_fee : 174.88
# cagr_w_fee      : 39.03
# mdd_w_fee       : 58.55
# investing_days  : 1120
# ==============================
# ======Investment Summary======
# Strategy        : Volatility Breakout_0.7_120cut_highest5%
# total_return    : 148.71
# cagr            : 35.08
# mdd             : 49.26
# total_return_w_fee : 166.72
# cagr_w_fee      : 38.23
# mdd_w_fee       : 46.38
# investing_days  : 1106
# ==============================
# ======Investment Summary======
# Strategy        : Volatility Breakout_0.7_200cut_highest5%
# total_return    : 76.45
# cagr            : 22.15
# mdd             : 45.8
# total_return_w_fee : 89.04
# cagr_w_fee      : 25.15
# mdd_w_fee       : 42.3
# investing_days  : 1036
# ==============================
# ======Investment Summary======
# Strategy        : Volatility Breakout_0.9_5cut_highest5%
# total_return    : 75.41
# cagr            : 18.19
# mdd             : 70.05
# total_return_w_fee : 73.37
# cagr_w_fee      : 17.78
# mdd_w_fee       : 71.41
# investing_days  : 1227
# ==============================
# ======Investment Summary======
# Strategy        : Volatility Breakout_0.9_10cut_highest5%
# total_return    : 73.54
# cagr            : 17.82
# mdd             : 69.13
# total_return_w_fee : 64.58
# cagr_w_fee      : 15.98
# mdd_w_fee       : 70.73
# investing_days  : 1227
# ==============================
# ======Investment Summary======
# Strategy        : Volatility Breakout_0.9_20cut_highest5%
# total_return    : 55.76
# cagr            : 14.44
# mdd             : 71.41
# total_return_w_fee : 70.49
# cagr_w_fee      : 17.63
# mdd_w_fee       : 71.62
# investing_days  : 1199
# ==============================
# ======Investment Summary======
# Strategy        : Volatility Breakout_0.9_50cut_highest5%
# total_return    : 135.64
# cagr            : 32.22
# mdd             : 58.74
# total_return_w_fee : 169.82
# cagr_w_fee      : 38.19
# mdd_w_fee       : 58.82
# investing_days  : 1120
# ==============================
# ======Investment Summary======
# Strategy        : Volatility Breakout_0.9_120cut_highest5%
# total_return    : 148.71
# cagr            : 35.08
# mdd             : 49.26
# total_return_w_fee : 163.14
# cagr_w_fee      : 37.62
# mdd_w_fee       : 46.74
# investing_days  : 1106
# ==============================
# ======Investment Summary======
# Strategy        : Volatility Breakout_0.9_200cut_highest5%
# total_return    : 78.48
# cagr            : 22.64
# mdd             : 45.17
# total_return_w_fee : 84.9
# cagr_w_fee      : 24.18
# mdd_w_fee       : 43.38
# investing_days  : 1036
# ==============================
